# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
project_path = '/content/drive/MyDrive/dl_lecture_competition'
os.chdir(project_path)

# %%
# !pip install hydra-core --upgrade
# !pip install hdf5plugin
# Out:
# Requirement already satisfied: hydra-core in c:\users\yutot\dl_basics\dl_lecture_competition_pub\.venv\lib\site-packages (1.3.2)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\yutot\dl_basics\dl_lecture_competition_pub\.venv\lib\site-packages (from hydra-core) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\yutot\dl_basics\dl_lecture_competition_pub\.venv\lib\site-packages (from hydra-core) (4.9.3)
# Requirement already satisfied: packaging in c:\users\yutot\dl_basics\dl_lecture_competition_pub\.venv\lib\site-packages (from hydra-core) (24.1)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\yutot\dl_basics\dl_lecture_competition_pub\.venv\lib\site-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0.1)
# Requirement already satisfied: hdf5plugin in c:\users\yutot\dl_basics\dl_lecture_competition_pub\.venv\lib\site-packages (4.4.0)
# Requirement already satisfied: h5py in c:\users\yutot\dl_basics\dl_lecture_competition_pub\.venv\lib\site-packages (from hdf5plugin) (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\yutot\dl_basics\dl_lecture_competition_pub\.venv\lib\site-packages (from h5py->hdf5plugin) (1.26.4)

# %%
# %env HYDRA_FULL_ERROR=1
# %cd C:\Users\yutot\DL_Basics\dl_lecture_competition_pub
# !python main.py
# Out:
# env: HYDRA_FULL_ERROR=1
# C:\Users\yutot\DL_Basics\dl_lecture_competition_pub
# Traceback (most recent call last):
#   File "C:\Users\yutot\DL_Basics\dl_lecture_competition_pub\main.py", line 1, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'
